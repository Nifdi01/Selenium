# %%
import pandas as pd

# %%
data = pd.read_json('data.json')
data.tail()
# Out:
#                                                  title  \
# 170  LG gram (2022) 17Z90Q Ultra Lightweight Laptop...
# 171  2022 Newest HP ENVY x360 2-in-1 Laptop, 15.6" ...
# 172  LG Gram 16Z90P Laptop 16" Ultra-Lightweight, (...
# 173  Belkin Charging Station For Laptops - Charging...
# 174  Dell Vostro 3530 Laptops for Student & Busines...
#
#                                                  image      price rating  \
# 170  https://m.media-amazon.com/images/I/71Wbbw-Nd4...  $1,299,99    4.3
# 171  https://m.media-amazon.com/images/I/81L5le9+NZ...    $280,08    4.6
# 172  https://m.media-amazon.com/images/I/71SsE8kWTD...    $999,00    4.1
# 173  https://m.media-amazon.com/images/I/61etbF1lty...    $183,00    4.4
# 174  https://m.media-amazon.com/images/I/81jvugAJ1u...    $799,99   None
#
#                                                   link
# 170  https://www.amazon.com/LG-Lightweight-Display-...
# 171  https://www.amazon.com/HP-Micro-Edge-Quad-Core...
# ...

# %%
data.describe()
# Out:
#                                                     title image price rating  \
# count                                                 175   175   175    175
# unique                                                165   147   127     18
# top     MSI Stealth GS66 Gaming Laptop: Intel Core i9-...  None  None   None
# freq                                                    2    18    18     42
#
#         link
# count    175
# unique   134
# top     None
# freq      42
